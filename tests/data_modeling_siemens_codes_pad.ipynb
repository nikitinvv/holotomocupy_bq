# %%
import numpy as np
import dxchange
import holotomo
import matplotlib.pyplot as plt
import cv2
import xraylib
import random
import scipy.ndimage as ndimage
import tifffile

PLANCK_CONSTANT = 4.135667696e-18  # [keV*s]
SPEED_OF_LIGHT = 299792458  # [m/s]

# %matplotlib inline

# %% [markdown]
# # Init data sizes and parametes of the PXM of ID16A

# %%
n = 2**11  # object size in x,y
nz = 2**11  # object size in z    

voxelsize = 10e-9*2048/n # [m] object voxel size 
energy = 33.35  # [keV] x-ray energy    
wavelength = PLANCK_CONSTANT * SPEED_OF_LIGHT / energy # [m]
focusToDetectorDistance = 1.28 # [m]
sx0 = 3.7e-4 # [m] motor offset from the focal spot

ncodes = 4 # number of codes for structure illumination
z1 = np.tile(np.array([4.584e-3]),ncodes)-sx0 # positions of the sample (1 position is enough when using several codes)
z1p = np.tile(np.array([4e-3]),ncodes)-sx0 # positions of each code (1 position is enough when using several codes)
z2 = z1p-z1 # propagation distance between the sample and code
z2p = focusToDetectorDistance-z1p # propagation distance between the code and detector

magnifications = (z1+z2)/z1 # magnification when propagating from the sample to the code
norm_magnifications = magnifications/magnifications[0] # normalized magnifications
distances = (z1*z2)/(z1+z2) # propagation distances after switching from the point source wave to plane wave,
distances = distances*norm_magnifications**2 # scaled propagation distances due to magnified probes

magnifications2 = (z1p+z2p)/z1p # magnification when propagating from the code to the detector
distances2 = (z1p*z2p)/(z1p+z2p) # propagation distances after switching from the point source wave to plane wave,
norm_magnifications2 = magnifications2/magnifications2[0] # normalized magnifications
distances2 = distances2*norm_magnifications**2 # scaled propagation distances due to magnified probes
distances2 = distances2*(z1/z1p)**2

# %%
magnifications2
# Out:
# array([352.61707989, 352.61707989, 352.61707989, 352.61707989])

# %% [markdown]
# ## Form a siemens star

# %%
img = np.zeros((n, n, 3), np.uint8)
triangle = np.array([(n//16, n//2-n//32), (n//16, n//2+n//32), (n//2-n//128, n//2)], np.float32)
star = img[:,:,0]*0
for i in range(0, 360, 15):
    img = np.zeros((n, n, 3), np.uint8)
    degree = i
    theta = degree * np.pi / 180
    rot_mat = np.array([[np.cos(theta), -np.sin(theta)],
                        [np.sin(theta), np.cos(theta)]], np.float32)    
    rotated = cv2.gemm(triangle-n//2, rot_mat, 1, None, 1, flags=cv2.GEMM_2_T)+n//2
    cv2.fillPoly(img, [np.int32(rotated)], (255, 0, 0))
    star+=img[:,:,0]
[x,y] = np.meshgrid(np.arange(-n//2,n//2),np.arange(-n//2,n//2))
x = x/n*2
y = y/n*2
# add holes in triangles
circ = (x**2+y**2>0.385)+(x**2+y**2<0.365)
circ *= (x**2+y**2>0.053)+(x**2+y**2<0.05)
circ *= (x**2+y**2>0.0085)+(x**2+y**2<0.008)
star = star*circ/255

v = np.arange(-n//2,n//2)/n
[vx,vy] = np.meshgrid(v,v)
v = np.exp(-5*(vx**2+vy**2))
fu = np.fft.fftshift(np.fft.fftn(np.fft.fftshift(star)))
star = np.fft.fftshift(np.fft.ifftn(np.fft.fftshift(fu*v))).real

# %% [markdown]
# ## Compute transmittance function for 600nm thick gold siemens star

# %%
delta = 1-xraylib.Refractive_Index_Re('Au',energy,19.3)
beta = xraylib.Refractive_Index_Im('Au',energy,19.3)

thickness = 600e-9/voxelsize # siemens star thickness in pixels
# form Transmittance function
u = star*(-delta+1j*beta) # note -delta
Ru = u*thickness 
psi = np.exp(1j * Ru * voxelsize * 2 * np.pi / wavelength)[np.newaxis].astype('complex64')

# %%
fig, axs = plt.subplots(1, 2, figsize=(9, 4))
im=axs[0].imshow(np.abs(psi[0]),cmap='gray')
axs[0].set_title('amplitude')
fig.colorbar(im)
im=axs[1].imshow(np.angle(psi[0]),cmap='gray')
axs[1].set_title('phase')
fig.colorbar(im)

# %% [markdown]
# ## Form tranmistance function for the code made of gold with 1um feature size, and 3um thickness

# %%
# make some large global code first
# random.seed(10)
# nill = 2**13
# ill_global = np.zeros([4,nill,nill],dtype='bool')
# for k in  range(ill_global.shape[0]):
#     ill0 = np.zeros([nill*nill],dtype='bool')
#     ill_ids = random.sample(range(0, nill*nill), nill*nill//2)
#     ill0[ill_ids] = 1
#     ill_global[k] = ill0.reshape(nill,nill)
# np.save('ill_global',ill_global)
ill_global = np.load('ill_global.npy')
# form codes for simulations
ill_feature_size = 1e-6
nn = 1024
voxelsizen = 10e-9*2048/nn # [m] object voxel size 
nill = int(nn*voxelsizen*magnifications[0]//(ill_feature_size*2))*2
ill = np.zeros([ncodes,nill,nill],dtype='bool')
for k in  range(ill.shape[0]):
    ill0 = ill_global[k]
    ill[k] = ill0[ill0.shape[0]//2-nill//2:ill0.shape[0]//2+(nill)//2,ill0.shape[1]//2-nill//2:ill0.shape[1]//2+(nill)//2]#.reshape(nill,nill)
ill = ndimage.zoom(ill,[1,nn/nill,nn/nill],order=0,grid_mode=True,mode='grid-wrap')

delta = 1-xraylib.Refractive_Index_Re('Au',energy,19.3)
beta = xraylib.Refractive_Index_Im('Au',energy,19.3)

thickness = 3*1e-6/voxelsizen # thickness in pixels

# form Transmittance function
Rill = ill*(-delta+1j*beta)*thickness 

# v = np.arange(-nn//2,nn//2)/nn
# [vx,vy] = np.meshgrid(v,v)
# v = np.exp(-20*(vx**2+vy**2))
# fu = np.fft.fftshift(np.fft.fftn(np.fft.fftshift(Rill)))
# Rill = np.fft.fftshift(np.fft.ifftn(np.fft.fftshift(fu*v)))
# Rill = ndimage.zoom(Rill,(1,n//nn,n/nn),order=0)
psiill = np.exp(1j * Rill * voxelsizen * 2 * np.pi / wavelength).astype('complex64')
psiill0 = psiill.copy()
psiill = ndimage.zoom(psiill,(1,n//nn,n//nn),order=0)#,grid_mode=False,mode='grid-wrap',prefilter=False)
np.linalg.norm(psiill0-psiill[:,::2,::2])
# Out:
# 0.0

# %%
fig, axs = plt.subplots(1, 2, figsize=(9, 4))
im=axs[0].imshow(np.abs(psiill[0,250:260,250:260]),cmap='gray')
axs[0].set_title('zoomed amplitude')
fig.colorbar(im)
im=axs[1].imshow(np.angle(psiill[0]),cmap='gray')
axs[1].set_title('phase')
fig.colorbar(im)

# %% [markdown]
# ## Read one probe

# %%
prb = np.ones([ncodes,nz,n],dtype='complex64')

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 7))
im=axs[0].imshow(np.abs(prb[0]),cmap='gray')
axs[0].set_title('scaled probe at z1[0], amplitude')
fig.colorbar(im)
im=axs[1].imshow(np.angle(prb[0]),cmap='gray')
axs[1].set_title('scaled probe at z1[0], phase')
fig.colorbar(im)

# %% [markdown]
# ## Create a solver class for holography, note the class has additional parameters distances2 to be able to compute Fresnel propagation between the sample and probe

# %%
pslv = holotomo.SolverHolo(1, nz, n, 1, voxelsize, energy, distances, norm_magnifications, distances2)

# %% [markdown]
# ## Model data

# %%
fpsi = pslv.fwd_holo_batch(psi,prb,psiill)
fflat = pslv.fwd_holo_batch(psi*0+1,prb,psiill)

# %% [markdown]
# ## Take squared absolute value to simulate data on the detector, flat fields, and data with homogeneous flat fields

# %%
data = np.abs(fpsi)**2
flat = np.abs(fflat)**2

# %% [markdown]
# ## Show data and flat fields for different codes

# %%
fig, axs = plt.subplots(2, 2, figsize=(9, 9))
im=axs[0,0].imshow(data[0,0],cmap='gray')
axs[0,0].set_title('data, code=0')
fig.colorbar(im)
im=axs[0,1].imshow(flat[0,0],cmap='gray')
axs[0,1].set_title('flat, code=0')
fig.colorbar(im)
im=axs[1,0].imshow(data[1,0],cmap='gray')
axs[1,0].set_title('data, code=1')
fig.colorbar(im)
im=axs[1,1].imshow(flat[1,0],cmap='gray')
axs[1,1].set_title('flat, code=1')
fig.colorbar(im)

# %% [markdown]
# # Save data and flat fields

# %%
for k in range(ncodes):
    dxchange.write_tiff(data[k],f'data/modeling/data_siemens_{n}_{k}',overwrite=True)
for k in range(ncodes):
    dxchange.write_tiff(flat[k,0],f'data/modeling/flat_siemens_{n}_{k}',overwrite=True)
for k in range(ncodes):
    dxchange.write_tiff(np.abs(psiill[k]),f'data/modeling/codes_siemens_{n}_{k}_amp',overwrite=True)
    dxchange.write_tiff(np.angle(psiill[k]),f'data/modeling/codes_siemens_{n}_{k}_angle',overwrite=True)

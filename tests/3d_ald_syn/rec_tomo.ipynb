# %%
import numpy as np
import dxchange
import holotomo
import matplotlib.pyplot as plt
import cupy as cp
import scipy.ndimage as ndimage
import numpy as np
import sys
import tomoalign
from skimage.metrics import structural_similarity as ssim
from matplotlib_scalebar.scalebar import ScaleBar
# %matplotlib inline

# %%
cp.cuda.Device(0).use()
ntheta = 180  # number of angles (rotations)
ptheta = 180  # holography chunk size for GPU processing
binning = 0
niter = 33
iter_step = 8
ndist = 4
st = 0
same_probe = True
flg_show = True

theta = np.linspace(0, np.pi, ntheta).astype('float32')  # projection angles


cropx_left = 0
cropx_right = 0
cropy_up = 0
cropy_down = 0

# cropx_left = 256
# cropx_right = 256
# cropy_up = 256
# cropy_down = 256

n = (256-cropx_left-cropx_right)//2**binning

ne = 512//2**binning

# ID16a setup
detector_pixelsize = 3e-6
energy = 17.05 #[keV] xray energy
focusToDetectorDistance = 1.208 # [m]
sx0 = -2.493e-3
z1 = np.array([1.5335e-3,1.7065e-3,2.3975e-3,3.8320e-3])[:ndist]-sx0
z2 = focusToDetectorDistance-z1
distances = (z1*z2)/focusToDetectorDistance
magnifications = focusToDetectorDistance/z1
voxelsize = detector_pixelsize/magnifications[0]*2**binning*2048/n  # object voxel size

norm_magnifications = magnifications/magnifications[0]
# scaled propagation distances due to magnified probes
distances = distances*norm_magnifications**2

z1p = z1[0]  # positions of the probe for reconstruction
z2p = z1-np.tile(z1p, len(z1))
# magnification when propagating from the probe plane to the detector
magnifications2 = (z1p+z2p)/z1p
# propagation distances after switching from the point source wave to plane wave,
distances2 = (z1p*z2p)/(z1p+z2p)
norm_magnifications2 = magnifications2/(z1p/z1[0])  # 
# scaled propagation distances due to magnified probes
distances2 = distances2*norm_magnifications2**2
distances2 = distances2*(z1p/z1)**2
pslv = holotomo.SolverHolo(ntheta, n, ne, ptheta, voxelsize, energy, distances, norm_magnifications, distances2,same_probe=same_probe)
# Out:
# 512

# %%
pslv = holotomo.SolverHolo(ntheta, n, ne, ptheta, voxelsize, energy, distances, norm_magnifications, distances2,same_probe=same_probe) 
tslv = holotomo.SolverTomo(theta, ntheta, ne, ne, ne, ne/2)

iter = 2048
init = np.zeros([ne,ne,ne],dtype='complex64')
data_abs = dxchange.read_tiff(f'/data/vnikitin/holo/3d_ald_syn/rabs_{n}_{ntheta}_{ndist}_{st}/r{iter:05}.tiff')
data_angle = dxchange.read_tiff(f'/data/vnikitin/holo/3d_ald_syn/r_{n}_{ntheta}_{ndist}_{st}/r{iter:05}.tiff')
data = pslv.logtomo(data_abs*np.exp(1j*data_angle))

# plt.imshow(data[:,250],cmap='gray')
# plt.colorbar()    
# plt.show()
# data = cp.array(data[:,ne//2-n//2:ne//2+n//2,ne//2-n//2:ne//2+n//2].astype('complex64'))
# init = cp.zeros([n,n,n],dtype='complex64')
# print(iter)
data =cp.array(data)
init= cp.array(init)

u = tslv.cg_tomo(data, init, 256,1)
# dxchange.write_tiff(u.real.get(), f'/data/vnikitin/holo/3d_ald/rpetersame_probe_{same_prb}_{n}_{ntheta}_{ndist}/cgfull/r_{iter:04}',overwrite=True)
dxchange.write_tiff(u.real.get(), f'/data/vnikitin/holo/3d_ald_syn/r_{n}_{ntheta}_{ndist}/cgfull/r_{iter:04}',overwrite=True)
# Out:
# 512

# %%
iter = 2048

offset = 16
rec = dxchange.read_tiff(f'/data/vnikitin/holo/3d_ald_syn/r_{n}_{ntheta}_{ndist}/cgfull/r_{iter:04}.tiff')
delta = dxchange.read_tiff('/data/vnikitin/modeling/3d_ald_syn/delta.tiff')

print(rec.shape)
PLANCK_CONSTANT = 4.135667696e-18  # [keV*s]
SPEED_OF_LIGHT = 299792458  # [m/s]
c = PLANCK_CONSTANT * SPEED_OF_LIGHT / 17.05
print(c)


voxelsize = 7.999668874172185e-08
c = c/voxelsize/np.pi/2
c=1
rec = rec[ne//2-n//2:ne//2+n//2,ne//2-n//2:ne//2+n//2,ne//2-n//2:ne//2+n//2]#-(136-50)/100*1e-7

err = np.linalg.norm(delta[n//2]-rec[n//2])/np.linalg.norm(delta[n//2])

s = ssim(rec[n//2,n//4:-n//4,n//4:-n//4],delta[n//2,n//4:-n//4,n//4:-n//4],data_range=np.amax(delta)-np.amin(delta))
# s = ssim(rec[n//2,:],delta[n//2,:],data_range=np.amax(delta)-np.amin(delta))
fig, ax = plt.subplots(1, figsize=(3, 3))
plt.imshow(-rec[n//2],cmap='gray',vmax=2.526992e-06,vmin=0)
ax.add_artist(ScaleBar(voxelsize,location='lower right'))
plt.colorbar()
plt.text(10,242,f'SSIM {s:.2}',backgroundcolor='w',size=11)
# plt.text(170,50,f'error',backgroundcolor='w',size=11)
# plt.text(170,80,f'{s:.3f}',backgroundcolor='w',size=11)
# error: {err:.3f}',size=12.5)
plt.savefig(f'figs/rech{iter}.png',dpi=300,bbox_inches='tight')
fig, ax = plt.subplots(1, figsize=(3, 3))
plt.imshow(delta[n//2,:]-rec[n//2],cmap='gray',vmax=1e-06,vmin=-1e-06)
plt.text(10,242,f'SSIM {s:.2}',backgroundcolor='w',size=11)
ax.add_artist(ScaleBar(voxelsize,location='lower right'))
plt.colorbar()
# plt.axis('off')
plt.savefig(f'figs/diffh{iter}.png',dpi=300,bbox_inches='tight')


# err = np.linalg.norm(delta[:,n//2-offset,:]-rec[ne//2-n//2:ne//2+n//2,ne//2-offset,ne//2-n//2:ne//2+n//2]*c)/np.linalg.norm(delta[:,n//2-16,:])
# for k in range(100,200,4):#+(172-100)/100*1e-7
rec=rec+np.mean(delta[:,n//2-offset,:]-rec[:,n//2-offset,:])




# s = ssim(rec[n//4:-n//4,n//2-offset,n//4:-n//4],delta[n//4:-n//4,n//2-offset,n//4:-n//4],data_range=np.amax(delta)-np.amin(delta))
s = ssim(rec[n//6:-n//6,n//2,n//6:-n//6],delta[n//6:-n//6,n//2,n//6:-n//6],data_range=np.amax(delta)-np.amin(delta))

# s = ssim(rec[:,n//2-offset,:],delta[:,n//2-offset,:],data_range=np.amax(delta[:,n//2-offset,:]*2)-np.amin(delta[:,n//2-offset,:]))
    # print(s,k)
err = np.linalg.norm(rec[:,n//2-offset,:]-delta[:,n//2-offset,:])/np.linalg.norm(delta[:,n//2-offset,:])

fig, ax = plt.subplots(1, figsize=(3, 3))
plt.imshow(-rec[:,n//2-offset,:],cmap='gray',vmax=2.526992e-06,vmin=0)
plt.text(10,242,f'SSIM {s:.2}',backgroundcolor='w',size=11)
ax.add_artist(ScaleBar(voxelsize,location='lower right'))
plt.colorbar()
plt.savefig(f'figs/recv{iter}.png',dpi=300,bbox_inches='tight')

fig, ax = plt.subplots(1, figsize=(3, 3))
plt.imshow(delta[:,n//2-offset,:]-rec[:,n//2-offset,:],cmap='gray',vmax=1e-06,vmin=-1e-06)
plt.text(10,242,f'SSIM {s:.2}',backgroundcolor='w',size=11)
ax.add_artist(ScaleBar(voxelsize,location='lower right'))
plt.colorbar()
# plt.axis('off')
plt.savefig(f'figs/diffv{iter}.png',dpi=300,bbox_inches='tight')
print(np.mean(delta[:,n//2-offset,:]-rec[:,n//2-offset,:]))
# Out:
# (512, 512, 512)
# 7.271800492991418e-11
# 2.3980817e-14

# %%
c = np.load(f'/data/vnikitin/holo/3d_ald_syn/conv_{n}_{ntheta}_{ndist}_{st}.npy')
fig = plt.figure(figsize=(7,3))
ax = fig.add_subplot(1,1,1)
ax.set_yscale('log')
ax.plot(np.arange(0,2048),c[:2048],label='noise free')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylabel('$L_2$-norm error',fontsize=16)
plt.xlabel('iter',fontsize=16)
plt.savefig(f'figs/conv.png',dpi=300,bbox_inches='tight')

c = np.load(f'/data/vnikitin/holo/3d_ald_syn/conv_{n}_{ntheta}_{ndist}_{st}noise.npy')
# fig = plt.figure(figsize=(7,3))
# ax = fig.add_subplot(1,1,1)
# ax.set_yscale('log')
ax.loglog(np.arange(0,2048),c[:2048],label='Gaussian noise')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylabel('$L_2$-norm error',fontsize=16)
plt.xlabel('iter',fontsize=16)
plt.legend(fontsize=14)
plt.savefig(f'figs/convnoise.png',dpi=300,bbox_inches='tight')

# %%
iter = 2048

offset = 8
rec = dxchange.read_tiff(f'/data/vnikitin/holo/3d_ald_syn/r_{n}_{ntheta}_{ndist}/cgfull/r_{iter:04}.tiff')
delta = dxchange.read_tiff('/data/vnikitin/modeling/3d_ald_syn/delta.tiff')

rec = rec[ne//2-n//2:ne//2+n//2,ne//2-n//2:ne//2+n//2,ne//2-n//2:ne//2+n//2]
#for k in range (20,40):
rec=rec-np.mean(rec[n//6:-n//6,n//2-offset,n//6:-n//6]-delta[n//6:-n//6,n//2-offset,n//6:-n//6])
# rec=rec-np.mean(rec[n//4:-n//4,n//2,n//4:-n//4]-delta[n//4:-n//4,n//2,n//4:-n//4])

    #s = ssim(rec[n//4:-n//4,n//2-offset,n//4:-n//4],delta[n//4:-n//4,n//2-offset,n//4:-n//4],data_range=np.amax(delta)-np.amin(delta))
s = ssim(rec[n//6:-n//6,n//2-offset,n//6:-n//6],delta[n//6:-n//6,n//2-offset,n//6:-n//6],data_range=np.amax(delta)-np.amin(delta))
# print(k,s)
err = np.linalg.norm(rec[:,n//2-offset,:]-delta[:,n//2-offset,:])/np.linalg.norm(delta[:,n//2-offset,:])

fig, ax = plt.subplots(1, figsize=(3, 3))
plt.imshow(-rec[:,n//2-offset,:],cmap='gray',vmax=2.526992e-06,vmin=0)
plt.text(10,242,f'SSIM {s:.2}',backgroundcolor='w',size=11)
ax.add_artist(ScaleBar(voxelsize,location='lower right'))
plt.colorbar()
plt.savefig(f'figs/recv{iter}.png',dpi=300,bbox_inches='tight')

############################################
iter = 2048
rec = dxchange.read_tiff(f'/data/vnikitin/holo/3d_ald_syn/r_{n}_{ntheta}_{ndist}/cgfull/r_{iter:04}noise.tiff')
delta = dxchange.read_tiff('/data/vnikitin/modeling/3d_ald_syn/delta.tiff')

rec = rec[ne//2-n//2:ne//2+n//2,ne//2-n//2:ne//2+n//2,ne//2-n//2:ne//2+n//2]
rec=rec+np.mean(delta[:,n//2-offset,:]-rec[:,n//2-offset,:])

#s = ssim(rec[n//4:-n//4,n//2-offset,n//4:-n//4],delta[n//4:-n//4,n//2-offset,n//4:-n//4],data_range=np.amax(delta)-np.amin(delta))
s = ssim(rec[n//6:-n//6,n//2,n//6:-n//6],delta[n//6:-n//6,n//2,n//6:-n//6],data_range=np.amax(delta)-np.amin(delta))
err = np.linalg.norm(rec[:,n//2-offset,:]-delta[:,n//2-offset,:])/np.linalg.norm(delta[:,n//2-offset,:])

fig, ax = plt.subplots(1, figsize=(3, 3))
plt.imshow(-rec[:,n//2-offset,:],cmap='gray',vmax=2.526992e-06,vmin=0)
plt.text(10,242,f'SSIM {s:.2}',backgroundcolor='w',size=11)
ax.add_artist(ScaleBar(voxelsize,location='lower right'))
plt.colorbar()
plt.savefig(f'figs/recv{iter}noise.png',dpi=300,bbox_inches='tight')


############################################
iter = 3984
rec = dxchange.read_tiff(f'/data/vnikitin/holo/3d_ald_syn_noprobe/r_{n}_{ntheta}_{ndist}/cgfull/r_{iter:04}.tiff')
delta = dxchange.read_tiff('/data/vnikitin/modeling/3d_ald_syn/delta.tiff')

rec = rec[ne//2-n//2:ne//2+n//2,ne//2-n//2:ne//2+n//2,ne//2-n//2:ne//2+n//2]
rec=rec+np.mean(delta[:,n//2-offset,:]-rec[:,n//2-offset,:])+0.55e-6

#s = ssim(rec[n//4:-n//4,n//2-offset,n//4:-n//4],delta[n//4:-n//4,n//2-offset,n//4:-n//4],data_range=np.amax(delta)-np.amin(delta))
s = ssim(rec[n//6:-n//6,n//2,n//6:-n//6],delta[n//6:-n//6,n//2,n//6:-n//6],data_range=np.amax(delta)-np.amin(delta))
err = np.linalg.norm(rec[:,n//2-offset,:]-delta[:,n//2-offset,:])/np.linalg.norm(delta[:,n//2-offset,:])

fig, ax = plt.subplots(1, figsize=(3, 3))
plt.imshow(-rec[:,n//2-offset,:],cmap='gray',vmax=2.526992e-06,vmin=0)
plt.text(10,242,f'SSIM {s:.2}',backgroundcolor='w',size=11)
ax.add_artist(ScaleBar(voxelsize,location='lower right'))
plt.colorbar()
plt.savefig(f'figs/recv{iter}noprobe.png',dpi=300,bbox_inches='tight')

############################################
iter = 2048+1024
rec = dxchange.read_tiff(f'/data/vnikitin/holo/3d_ald_syn_noprobe_noise/r_{n}_{ntheta}_{ndist}/cgfull/r_{iter:04}.tiff')
delta = dxchange.read_tiff('/data/vnikitin/modeling/3d_ald_syn/delta.tiff')

rec = rec[ne//2-n//2:ne//2+n//2,ne//2-n//2:ne//2+n//2,ne//2-n//2:ne//2+n//2]
rec=rec+np.mean(delta[:,n//2-offset,:]-rec[:,n//2-offset,:])+0.15e-6

#s = ssim(rec[n//4:-n//4,n//2-offset,n//4:-n//4],delta[n//4:-n//4,n//2-offset,n//4:-n//4],data_range=np.amax(delta)-np.amin(delta))
s = ssim(rec[n//6:-n//6,n//2,n//6:-n//6],delta[n//6:-n//6,n//2,n//6:-n//6],data_range=np.amax(delta)-np.amin(delta))
err = np.linalg.norm(rec[:,n//2-offset,:]-delta[:,n//2-offset,:])/np.linalg.norm(delta[:,n//2-offset,:])

fig, ax = plt.subplots(1, figsize=(3, 3))
plt.imshow(-rec[:,n//2-offset,:],cmap='gray',vmax=2.526992e-06,vmin=0)
plt.text(10,242,f'SSIM {s:.2}',backgroundcolor='w',size=11)
ax.add_artist(ScaleBar(voxelsize,location='lower right'))
plt.colorbar()
plt.savefig(f'figs/recv{iter}noprobenoise.png',dpi=300,bbox_inches='tight')
